# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('Biomass.csv')
data
# Out:
#        Geopolitical Entity Geopolitical Entity (Id)  Year       Sector  \
# 0                  Austria                       AT  2008  Agriculture
# 1                  Austria                       AT  2008  Agriculture
# 2                  Austria                       AT  2008  Agriculture
# 3                  Austria                       AT  2008  Agriculture
# 4                  Austria                       AT  2008  Agriculture
# ...                    ...                      ...   ...          ...
# 101955      United Kingdom                       UK  2017     Forestry
# 101956      United Kingdom                       UK  2017     Forestry
# 101957      United Kingdom                       UK  2017     Forestry
# 101958      United Kingdom                       UK  2017     Forestry
# 101959      United Kingdom                       UK  2017     Forestry
#
#                    Level_Sankey Level_Sankey (Id) Lifecycle Step  \
# 0          L2 - Biomass by type                L2        Exports
# 1          L2 - Biomass by type                L2        Exports
# 2          L2 - Biomass by type                L2        Exports
# 3          L2 - Biomass by type                L2        Exports
# 4          L2 - Biomass by type                L2        Exports
# ...                         ...               ...            ...
# 101955  L3 - Biomass components                L3           Uses
# 101956  L3 - Biomass components                L3           Uses
# 101957  L3 - Biomass components                L3           Uses
# 101958  L3 - Biomass components                L3           Uses
# 101959  L3 - Biomass components                L3           Uses
#
#                                 Source Source (Id)               Target  \
# 0                       Biomass supply          A4              Exports
# 1                       Biomass supply          A4              Exports
# 2                         Biomaterials          A6              Exports
# 3                         Biomaterials          A6              Exports
# 4                       Feed & bedding          A9              Exports
# ...                                ...         ...                  ...
# 101955     Supply (Post Consumer Wood)       F06_3  Solid wood products
# 101956  Supply (Primary woody biomass)       F06_5  Solid wood products
# 101957  Supply (Primary woody biomass)       F06_5  Solid wood products
# 101958  Supply (Primary woody biomass)       F06_5            Wood pulp
# 101959  Supply (Primary woody biomass)       F06_5            Wood pulp
#
#        Target (Id)                   Flow  Flow (Id)  \
# 0              A14    Agriculture biomass  AGRI_AGGR
# 1              A14    Agriculture biomass  AGRI_AGGR
# 2              A14    Agriculture biomass  AGRI_AGGR
# 3              A14    Agriculture biomass  AGRI_AGGR
# 4              A14    Agriculture biomass  AGRI_AGGR
# ...            ...                    ...        ...
# 101955         F09     Post-consumer wood   P_CONS_W
# 101956         F09  Primary woody biomass  W_BIOMASS
# 101957         F09  Primary woody biomass  W_BIOMASS
# 101958         F08  Primary woody biomass  W_BIOMASS
# 101959         F08  Primary woody biomass  W_BIOMASS
#
#                                       Unit     Unit (Id)  \
# 0       1000 T of dry matter (Gross trade)  KT_DRY_GROSS
# 1         1000 T of dry matter (Net trade)    KT_DRY_NET
# 2       1000 T of dry matter (Gross trade)  KT_DRY_GROSS
# 3         1000 T of dry matter (Net trade)    KT_DRY_NET
# 4       1000 T of dry matter (Gross trade)  KT_DRY_GROSS
# ...                                    ...           ...
# 101955    1000 T of dry matter (Net trade)    KT_DRY_NET
# 101956  1000 T of dry matter (Gross trade)  KT_DRY_GROSS
# 101957    1000 T of dry matter (Net trade)    KT_DRY_NET
# 101958  1000 T of dry matter (Gross trade)  KT_DRY_GROSS
# 101959    1000 T of dry matter (Net trade)    KT_DRY_NET
#
#         Value (THOUSAND TONS)
# 0                 1236.146647
# 1                    0.000000
# 2                  563.395620
# 3                    0.000000
# 4                 4469.214988
# ...                       ...
# 101955               0.000000
# 101956               0.000000
# 101957               0.000000
# 101958               0.000000
# 101959               0.000000
#
# [101960 rows x 16 columns]

# %%
ax = sns.boxplot(x="Sector", y= "Value (THOUSAND TONS)", data=data)

# %%
data[['Value (THOUSAND TONS)']] = np.log(data[['Value (THOUSAND TONS)']]) 
ax = sns.boxplot(x="Sector", y= "Value (THOUSAND TONS)", data=data)
# Out:
# <ipython-input-42-5a10edfb316b>:1: RuntimeWarning: invalid value encountered in log
#   data[['Value (THOUSAND TONS)']] = np.log(data[['Value (THOUSAND TONS)']])
